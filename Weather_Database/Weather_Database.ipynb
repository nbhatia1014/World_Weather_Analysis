# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8017826767103057fe931e3812d00934

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform (low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform (low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Create an empty list to hold the weather data. 
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#Create Counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather['sys']['country']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                    
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | asnaes
# Processing Record 2 of Set 1 | dolores
# Processing Record 3 of Set 1 | port hedland
# Processing Record 4 of Set 1 | tual
# Processing Record 5 of Set 1 | te anau
# Processing Record 6 of Set 1 | bandar-e lengeh
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | romny
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | sal rei
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | lavrentiya
# Processing Record 16 of Set 1 | ghanzi
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | collie
# Processing Record 21 of Set 1 | marquette
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | novikovo
# Processing Record 24 of Set 1 | burnie
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | rantepao
# Processing Record 28 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | staryy oskol
# Processing Record 32 of Set 1 | kununurra
# Processing Record 33 of Set 1 | huarmey
# Processing Record 34 of Set 1 | aquin
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | bushenyi
# Processing Record 38 of Set 1 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | kondopoga
# Processing Record 41 of Set 1 | isla vista
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | tukan
# Processing Record 50 of Set 1 | antofagasta
# Processing Record 1 of Set 2 | hohhot
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | grand-santi
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | vardo
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | klodzko
# Processing Record 11 of Set 2 | alofi
# Processing Record 12 of Set 2 | guerrero negro
# Processing Record 13 of Set 2 | bandar
# Processing Record 14 of Set 2 | wick
# Processing Record 15 of Set 2 | khuzhir
# Processing Record 16 of Set 2 | jaru
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | padang
# Processing Record 19 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 20 of Set 2 | itaituba
# Processing Record 21 of Set 2 | point pedro
# Processing Record 22 of Set 2 | gravdal
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | saint-pierre
# Processing Record 26 of Set 2 | balabac
# Processing Record 27 of Set 2 | vao
# Processing Record 28 of Set 2 | kerteh
# City not found. Skipping...
# Processing Record 29 of Set 2 | pierre
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | gold coast
# Processing Record 32 of Set 2 | yumen
# Processing Record 33 of Set 2 | floro
# Processing Record 34 of Set 2 | manzil tamim
# City not found. Skipping...
# Processing Record 35 of Set 2 | flinders
# Processing Record 36 of Set 2 | chernyshevskiy
# Processing Record 37 of Set 2 | kaputa
# Processing Record 38 of Set 2 | zolotinka
# City not found. Skipping...
# Processing Record 39 of Set 2 | butembo
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | carlyle
# Processing Record 42 of Set 2 | husavik
# Processing Record 43 of Set 2 | hitachi
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | zhangjiakou
# Processing Record 46 of Set 2 | marovoay
# Processing Record 47 of Set 2 | thilogne
# City not found. Skipping...
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | umba
# Processing Record 2 of Set 3 | kyra
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | acarau
# Processing Record 6 of Set 3 | fort saint james
# Processing Record 7 of Set 3 | nam tha
# City not found. Skipping...
# Processing Record 8 of Set 3 | tianmen
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | klimovo
# Processing Record 11 of Set 3 | bemidji
# Processing Record 12 of Set 3 | menongue
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | havelock
# Processing Record 15 of Set 3 | qabis
# City not found. Skipping...
# Processing Record 16 of Set 3 | faanui
# Processing Record 17 of Set 3 | yinchuan
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | san juan
# Processing Record 20 of Set 3 | puksoozero
# Processing Record 21 of Set 3 | sitka
# Processing Record 22 of Set 3 | aktau
# Processing Record 23 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 3 | coquimbo
# Processing Record 25 of Set 3 | kaka
# Processing Record 26 of Set 3 | kozan
# Processing Record 27 of Set 3 | malanje
# Processing Record 28 of Set 3 | palmer
# Processing Record 29 of Set 3 | joao pinheiro
# Processing Record 30 of Set 3 | mahebourg
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | pemberton
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | natal
# Processing Record 35 of Set 3 | damavand
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | altay
# Processing Record 38 of Set 3 | ewa beach
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | beloha
# Processing Record 42 of Set 3 | airai
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | ormara
# Processing Record 45 of Set 3 | kabompo
# Processing Record 46 of Set 3 | flin flon
# Processing Record 47 of Set 3 | ayan
# Processing Record 48 of Set 3 | caravelas
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | aklavik
# Processing Record 2 of Set 4 | cabadiangan
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | zaraza
# Processing Record 5 of Set 4 | alphen
# Processing Record 6 of Set 4 | santa rosalia
# Processing Record 7 of Set 4 | asheville
# Processing Record 8 of Set 4 | eureka
# Processing Record 9 of Set 4 | talnakh
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | komsomolskiy
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | holboca
# Processing Record 16 of Set 4 | tautira
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | merta
# Processing Record 19 of Set 4 | sorland
# Processing Record 20 of Set 4 | doka
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | vila franca do campo
# Processing Record 24 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 4 | manga
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | nemuro
# Processing Record 28 of Set 4 | mount hagen
# Processing Record 29 of Set 4 | port-gentil
# Processing Record 30 of Set 4 | sliema
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | mount gambier
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | chirongui
# Processing Record 36 of Set 4 | paamiut
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | butaritari
# Processing Record 43 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 4 | carberry
# Processing Record 45 of Set 4 | thongwa
# Processing Record 46 of Set 4 | port alfred
# Processing Record 47 of Set 4 | macenta
# Processing Record 48 of Set 4 | baghdad
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | taraz
# Processing Record 1 of Set 5 | olga
# Processing Record 2 of Set 5 | buala
# Processing Record 3 of Set 5 | gornopravdinsk
# Processing Record 4 of Set 5 | umm kaddadah
# Processing Record 5 of Set 5 | wenling
# Processing Record 6 of Set 5 | saint-augustin
# Processing Record 7 of Set 5 | esperance
# Processing Record 8 of Set 5 | devils lake
# Processing Record 9 of Set 5 | aswan
# Processing Record 10 of Set 5 | stephenville crossing
# Processing Record 11 of Set 5 | samarai
# Processing Record 12 of Set 5 | nayudupeta
# Processing Record 13 of Set 5 | kampot
# Processing Record 14 of Set 5 | necochea
# Processing Record 15 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 5 | moerai
# Processing Record 17 of Set 5 | christiana
# Processing Record 18 of Set 5 | wajima
# Processing Record 19 of Set 5 | taltal
# Processing Record 20 of Set 5 | urubicha
# Processing Record 21 of Set 5 | olafsvik
# Processing Record 22 of Set 5 | ibipeba
# Processing Record 23 of Set 5 | dorado
# Processing Record 24 of Set 5 | portland
# Processing Record 25 of Set 5 | tayginka
# Processing Record 26 of Set 5 | san policarpo
# Processing Record 27 of Set 5 | hambantota
# Processing Record 28 of Set 5 | revuca
# Processing Record 29 of Set 5 | westport
# Processing Record 30 of Set 5 | muros
# Processing Record 31 of Set 5 | sept-iles
# Processing Record 32 of Set 5 | puerto leguizamo
# Processing Record 33 of Set 5 | pionerskiy
# Processing Record 34 of Set 5 | sinnamary
# Processing Record 35 of Set 5 | dhidhdhoo
# Processing Record 36 of Set 5 | holice
# Processing Record 37 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 5 | ninh binh
# Processing Record 39 of Set 5 | shingu
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | kalemie
# Processing Record 42 of Set 5 | hirado
# Processing Record 43 of Set 5 | nikolskoye
# Processing Record 44 of Set 5 | san quintin
# Processing Record 45 of Set 5 | kutum
# Processing Record 46 of Set 5 | byron bay
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | kerteminde
# Processing Record 49 of Set 5 | karratha
# Processing Record 50 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 6 | tevaitoa
# Processing Record 3 of Set 6 | anadyr
# Processing Record 4 of Set 6 | krasnoturinsk
# Processing Record 5 of Set 6 | khalkhal
# Processing Record 6 of Set 6 | miyako
# Processing Record 7 of Set 6 | arman
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | ashqelon
# Processing Record 10 of Set 6 | sobradinho
# Processing Record 11 of Set 6 | bahia blanca
# Processing Record 12 of Set 6 | sakakah
# Processing Record 13 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 6 | abu samrah
# Processing Record 15 of Set 6 | cabedelo
# Processing Record 16 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | eenhana
# Processing Record 19 of Set 6 | shahr-e babak
# Processing Record 20 of Set 6 | carupano
# Processing Record 21 of Set 6 | la rioja
# Processing Record 22 of Set 6 | newala
# Processing Record 23 of Set 6 | saint-imier
# Processing Record 24 of Set 6 | luzon
# Processing Record 25 of Set 6 | saint-philippe
# Processing Record 26 of Set 6 | oranjemund
# Processing Record 27 of Set 6 | maiduguri
# Processing Record 28 of Set 6 | nishihara
# Processing Record 29 of Set 6 | fortuna
# Processing Record 30 of Set 6 | karatau
# Processing Record 31 of Set 6 | ailigandi
# Processing Record 32 of Set 6 | ancona
# Processing Record 33 of Set 6 | vichuga
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | henties bay
# Processing Record 36 of Set 6 | roald
# Processing Record 37 of Set 6 | kabanjahe
# Processing Record 38 of Set 6 | esil
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | bardiyah
# Processing Record 41 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 6 | rawson
# Processing Record 43 of Set 6 | hachinohe
# Processing Record 44 of Set 6 | babu
# Processing Record 45 of Set 6 | zambezi
# Processing Record 46 of Set 6 | klaksvik
# Processing Record 47 of Set 6 | vila velha
# Processing Record 48 of Set 6 | kudahuvadhoo
# Processing Record 49 of Set 6 | sokoni
# Processing Record 50 of Set 6 | balikpapan
# Processing Record 1 of Set 7 | polunochnoye
# Processing Record 2 of Set 7 | sambava
# Processing Record 3 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 4 of Set 7 | hays
# Processing Record 5 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 7 | havoysund
# Processing Record 7 of Set 7 | ahuimanu
# Processing Record 8 of Set 7 | el tigre
# Processing Record 9 of Set 7 | zhigansk
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | gazli
# Processing Record 12 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 7 | georgetown
# Processing Record 14 of Set 7 | sile
# Processing Record 15 of Set 7 | akyab
# Processing Record 16 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 7 | guiratinga
# Processing Record 20 of Set 7 | simao
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | sovetskiy
# Processing Record 23 of Set 7 | greenwood
# Processing Record 24 of Set 7 | port augusta
# Processing Record 25 of Set 7 | kapit
# Processing Record 26 of Set 7 | namibe
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | mattru
# Processing Record 29 of Set 7 | victoria
# Processing Record 30 of Set 7 | ouesso
# Processing Record 31 of Set 7 | carnarvon
# Processing Record 32 of Set 7 | clyde river
# Processing Record 33 of Set 7 | victor harbor
# Processing Record 34 of Set 7 | bembereke
# Processing Record 35 of Set 7 | shahganj
# Processing Record 36 of Set 7 | bukachacha
# Processing Record 37 of Set 7 | bugojno
# Processing Record 38 of Set 7 | easton
# Processing Record 39 of Set 7 | boyuibe
# Processing Record 40 of Set 7 | greytown
# Processing Record 41 of Set 7 | palaikastron
# Processing Record 42 of Set 7 | amapa
# Processing Record 43 of Set 7 | manadhoo
# Processing Record 44 of Set 7 | ginir
# Processing Record 45 of Set 7 | kodinar
# Processing Record 46 of Set 7 | port macquarie
# Processing Record 47 of Set 7 | paso de los toros
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | touros
# Processing Record 50 of Set 7 | north bend
# Processing Record 1 of Set 8 | krasnoselkup
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | san nicolas
# Processing Record 4 of Set 8 | alcaniz
# Processing Record 5 of Set 8 | raton
# Processing Record 6 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 8 | rincon
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | flekkefjord
# Processing Record 10 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 8 | chicama
# Processing Record 12 of Set 8 | panguipulli
# Processing Record 13 of Set 8 | tateyama
# Processing Record 14 of Set 8 | vestmanna
# Processing Record 15 of Set 8 | pontianak
# Processing Record 16 of Set 8 | saint george
# Processing Record 17 of Set 8 | ribeira grande
# Processing Record 18 of Set 8 | tsiroanomandidy
# Processing Record 19 of Set 8 | tazovskiy
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | jalu
# Processing Record 22 of Set 8 | ust-maya
# Processing Record 23 of Set 8 | pimentel
# Processing Record 24 of Set 8 | morehead
# Processing Record 25 of Set 8 | poum
# Processing Record 26 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 8 | poya
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | pandan
# Processing Record 30 of Set 8 | san andres
# Processing Record 31 of Set 8 | el vendrell
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | adrar
# Processing Record 35 of Set 8 | urucara
# Processing Record 36 of Set 8 | estelle
# Processing Record 37 of Set 8 | souillac
# Processing Record 38 of Set 8 | xinzhi
# Processing Record 39 of Set 8 | vanimo
# Processing Record 40 of Set 8 | faya
# Processing Record 41 of Set 8 | vredendal
# Processing Record 42 of Set 8 | kahama
# Processing Record 43 of Set 8 | broken hill
# Processing Record 44 of Set 8 | fort nelson
# Processing Record 45 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 8 | taoudenni
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | kloulklubed
# Processing Record 49 of Set 8 | akonolinga
# Processing Record 50 of Set 8 | camana
# Processing Record 1 of Set 9 | menzelinsk
# Processing Record 2 of Set 9 | iqaluit
# Processing Record 3 of Set 9 | avera
# Processing Record 4 of Set 9 | asht
# City not found. Skipping...
# Processing Record 5 of Set 9 | baykit
# Processing Record 6 of Set 9 | balaka
# Processing Record 7 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 9 | road town
# Processing Record 9 of Set 9 | azul
# Processing Record 10 of Set 9 | nadym
# Processing Record 11 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 12 of Set 9 | ustynivka
# Processing Record 13 of Set 9 | fonte boa
# Processing Record 14 of Set 9 | barcelos
# Processing Record 15 of Set 9 | marechal candido rondon
# Processing Record 16 of Set 9 | port blair
# Processing Record 17 of Set 9 | yerbabuena
# Processing Record 18 of Set 9 | nouadhibou
# Processing Record 19 of Set 9 | labuhan
# Processing Record 20 of Set 9 | libreville
# Processing Record 21 of Set 9 | valparaiso
# Processing Record 22 of Set 9 | morden
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | citta di castello
# Processing Record 25 of Set 9 | kaele
# Processing Record 26 of Set 9 | novopokrovka
# Processing Record 27 of Set 9 | srednekolymsk
# Processing Record 28 of Set 9 | belyy yar
# Processing Record 29 of Set 9 | ojinaga
# Processing Record 30 of Set 9 | mantes-la-ville
# Processing Record 31 of Set 9 | viedma
# Processing Record 32 of Set 9 | macherla
# Processing Record 33 of Set 9 | ossora
# Processing Record 34 of Set 9 | bulalacao
# Processing Record 35 of Set 9 | sri aman
# Processing Record 36 of Set 9 | russell
# Processing Record 37 of Set 9 | darnah
# Processing Record 38 of Set 9 | kieta
# Processing Record 39 of Set 9 | champerico
# Processing Record 40 of Set 9 | san patricio
# Processing Record 41 of Set 9 | narsaq
# Processing Record 42 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 9 | sola
# Processing Record 44 of Set 9 | nantucket
# Processing Record 45 of Set 9 | huanren
# Processing Record 46 of Set 9 | meulaboh
# Processing Record 47 of Set 9 | gondanglegi
# Processing Record 48 of Set 9 | jardim
# Processing Record 49 of Set 9 | pacific grove
# Processing Record 50 of Set 9 | oranjestad
# Processing Record 1 of Set 10 | minudasht
# Processing Record 2 of Set 10 | parabel
# Processing Record 3 of Set 10 | san miguel
# Processing Record 4 of Set 10 | kutulik
# Processing Record 5 of Set 10 | boundiali
# Processing Record 6 of Set 10 | kruisfontein
# Processing Record 7 of Set 10 | wakkanai
# Processing Record 8 of Set 10 | benghazi
# Processing Record 9 of Set 10 | tres lagoas
# Processing Record 10 of Set 10 | laguna
# Processing Record 11 of Set 10 | salina
# Processing Record 12 of Set 10 | dulce grande
# Processing Record 13 of Set 10 | corn island
# Processing Record 14 of Set 10 | meadow lake
# Processing Record 15 of Set 10 | mackenzie
# Processing Record 16 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 10 | ugoofaaru
# Processing Record 18 of Set 10 | hasaki
# Processing Record 19 of Set 10 | tigil
# Processing Record 20 of Set 10 | naugarzan
# City not found. Skipping...
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | vila
# Processing Record 23 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 10 | aguai
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | cradock
# Processing Record 27 of Set 10 | ishigaki
# Processing Record 28 of Set 10 | nangan
# Processing Record 29 of Set 10 | karasjok
# Processing Record 30 of Set 10 | terney
# Processing Record 31 of Set 10 | namatanai
# Processing Record 32 of Set 10 | skibbereen
# Processing Record 33 of Set 10 | pasighat
# Processing Record 34 of Set 10 | katherine
# Processing Record 35 of Set 10 | norman wells
# Processing Record 36 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 37 of Set 10 | calamar
# Processing Record 38 of Set 10 | honningsvag
# Processing Record 39 of Set 10 | maniitsoq
# Processing Record 40 of Set 10 | mbanza-ngungu
# Processing Record 41 of Set 10 | saldanha
# Processing Record 42 of Set 10 | chimbote
# Processing Record 43 of Set 10 | sioux lookout
# Processing Record 44 of Set 10 | nuuk
# Processing Record 45 of Set 10 | guane
# Processing Record 46 of Set 10 | talhar
# Processing Record 47 of Set 10 | sumbe
# Processing Record 48 of Set 10 | kapchorwa
# Processing Record 49 of Set 10 | kikwit
# Processing Record 50 of Set 10 | prince rupert
# Processing Record 1 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 11 | sattahip
# Processing Record 3 of Set 11 | rafai
# Processing Record 4 of Set 11 | sanghar
# Processing Record 5 of Set 11 | olinda
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | kimbe
# Processing Record 8 of Set 11 | kulu
# Processing Record 9 of Set 11 | toora-khem
# Processing Record 10 of Set 11 | kuruman
# Processing Record 11 of Set 11 | rio verde de mato grosso
# Processing Record 12 of Set 11 | ranong
# Processing Record 13 of Set 11 | kasongo-lunda
# Processing Record 14 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 15 of Set 11 | chimala
# Processing Record 16 of Set 11 | whitefish
# Processing Record 17 of Set 11 | nanortalik
# Processing Record 18 of Set 11 | san roque
# Processing Record 19 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 11 | ginda
# Processing Record 21 of Set 11 | provost
# Processing Record 22 of Set 11 | vikhorevka
# Processing Record 23 of Set 11 | gadsden
# Processing Record 24 of Set 11 | rio gallegos
# Processing Record 25 of Set 11 | kibre mengist
# Processing Record 26 of Set 11 | diffa
# Processing Record 27 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 28 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 29 of Set 11 | kuchl
# Processing Record 30 of Set 11 | omboue
# Processing Record 31 of Set 11 | ilo
# Processing Record 32 of Set 11 | dudinka
# Processing Record 33 of Set 11 | hell
# Processing Record 34 of Set 11 | sperkhias
# City not found. Skipping...
# Processing Record 35 of Set 11 | fort morgan
# Processing Record 36 of Set 11 | murovani kurylivtsi
# Processing Record 37 of Set 11 | turkistan
# Processing Record 38 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 11 | dengzhou
# Processing Record 40 of Set 11 | hornepayne
# Processing Record 41 of Set 11 | nioaque
# Processing Record 42 of Set 11 | manggar
# Processing Record 43 of Set 11 | carbondale
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | carutapera
# Processing Record 46 of Set 11 | palmerston north
# Processing Record 47 of Set 11 | tambopata
# Processing Record 48 of Set 11 | kamenka
# Processing Record 49 of Set 11 | grand gaube
# Processing Record 50 of Set 11 | amahai
# Processing Record 1 of Set 12 | bandarbeyla
# Processing Record 2 of Set 12 | inta
# Processing Record 3 of Set 12 | saint-francois
# Processing Record 4 of Set 12 | mozhaysk
# Processing Record 5 of Set 12 | warmbad
# Processing Record 6 of Set 12 | atar
# Processing Record 7 of Set 12 | murwillumbah
# Processing Record 8 of Set 12 | polewali
# Processing Record 9 of Set 12 | esik
# Processing Record 10 of Set 12 | filingue
# Processing Record 11 of Set 12 | miri
# Processing Record 12 of Set 12 | la ronge
# Processing Record 13 of Set 12 | ornskoldsvik
# Processing Record 14 of Set 12 | ambon
# Processing Record 15 of Set 12 | daru
# Processing Record 16 of Set 12 | marsa matruh
# Processing Record 17 of Set 12 | hwange
# Processing Record 18 of Set 12 | lorengau
# Processing Record 19 of Set 12 | franklin
# Processing Record 20 of Set 12 | khasan
# Processing Record 21 of Set 12 | san ignacio
# Processing Record 22 of Set 12 | san pedro
# Processing Record 23 of Set 12 | saint anthony
# Processing Record 24 of Set 12 | saint-georges
# Processing Record 25 of Set 12 | mayskiy
# Processing Record 26 of Set 12 | voh
# Processing Record 27 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 28 of Set 12 | katobu
# Processing Record 29 of Set 12 | inyonga
# Processing Record 30 of Set 12 | kamaishi
# Processing Record 31 of Set 12 | torbat-e jam
# Processing Record 32 of Set 12 | ganzhou
# Processing Record 33 of Set 12 | tuatapere
# Processing Record 34 of Set 12 | marsh harbour
# Processing Record 35 of Set 12 | ballina
# Processing Record 36 of Set 12 | atlantic city
# Processing Record 37 of Set 12 | praya
# Processing Record 38 of Set 12 | pallasovka
# Processing Record 39 of Set 12 | jumla
# Processing Record 40 of Set 12 | paraiso
# Processing Record 41 of Set 12 | chandur bazar
# Processing Record 42 of Set 12 | pochutla
# Processing Record 43 of Set 12 | suluova
# Processing Record 44 of Set 12 | qobustan
# Processing Record 45 of Set 12 | ankpa
# Processing Record 46 of Set 12 | tomatlan
# Processing Record 47 of Set 12 | nago
# Processing Record 48 of Set 12 | gander
# Processing Record 49 of Set 12 | channel-port aux basques
# Processing Record 50 of Set 12 | thunder bay
# Processing Record 1 of Set 13 | lang son
# Processing Record 2 of Set 13 | son la
# Processing Record 3 of Set 13 | trincomalee
# Processing Record 4 of Set 13 | punakha
# Processing Record 5 of Set 13 | bathsheba
# Processing Record 6 of Set 13 | kosh-agach
# Processing Record 7 of Set 13 | starkville
# Processing Record 8 of Set 13 | singaparna
# Processing Record 9 of Set 13 | fuerte olimpo
# Processing Record 10 of Set 13 | ashikaga
# Processing Record 11 of Set 13 | weligama
# Processing Record 12 of Set 13 | yakeshi
# Processing Record 13 of Set 13 | ponta do sol
# Processing Record 14 of Set 13 | strelka
# Processing Record 15 of Set 13 | owando
# Processing Record 16 of Set 13 | iskateley
# Processing Record 17 of Set 13 | rabo de peixe
# Processing Record 18 of Set 13 | pachino
# Processing Record 19 of Set 13 | udachnyy
# Processing Record 20 of Set 13 | dwarka
# Processing Record 21 of Set 13 | hovd
# Processing Record 22 of Set 13 | pailon
# Processing Record 23 of Set 13 | santa maria
# Processing Record 24 of Set 13 | lincoln
# Processing Record 25 of Set 13 | onda
# Processing Record 26 of Set 13 | moree
# Processing Record 27 of Set 13 | encheng
# Processing Record 28 of Set 13 | chapais
# Processing Record 29 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 13 | imbituba
# Processing Record 31 of Set 13 | yashkino
# Processing Record 32 of Set 13 | trairi
# Processing Record 33 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 13 | bartica
# Processing Record 35 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 13 | gazojak
# Processing Record 37 of Set 13 | athabasca
# Processing Record 38 of Set 13 | shepsi
# Processing Record 39 of Set 13 | antalaha
# Processing Record 40 of Set 13 | zdvinsk
# Processing Record 41 of Set 13 | davila
# Processing Record 42 of Set 13 | belmonte
# Processing Record 43 of Set 13 | berlevag
# Processing Record 44 of Set 13 | constitucion
# Processing Record 45 of Set 13 | progreso
# Processing Record 46 of Set 13 | oussouye
# Processing Record 47 of Set 13 | lyamino
# Processing Record 48 of Set 13 | salta
# Processing Record 49 of Set 13 | inongo
# Processing Record 50 of Set 13 | hobyo
# Processing Record 1 of Set 14 | macamic
# Processing Record 2 of Set 14 | manzanillo
# Processing Record 3 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 14 | porto empedocle
# Processing Record 5 of Set 14 | pastavy
# Processing Record 6 of Set 14 | sinjar
# Processing Record 7 of Set 14 | kardailovo
# Processing Record 8 of Set 14 | bhimunipatnam
# Processing Record 9 of Set 14 | hopfgarten
# Processing Record 10 of Set 14 | shar
# Processing Record 11 of Set 14 | otavi
# Processing Record 12 of Set 14 | kirakira
# Processing Record 13 of Set 14 | oistins
# Processing Record 14 of Set 14 | erenhot
# Processing Record 15 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 14 | tezu
# Processing Record 17 of Set 14 | vila do maio
# Processing Record 18 of Set 14 | novokuznetsk
# Processing Record 19 of Set 14 | cabra
# Processing Record 20 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 14 | envira
# Processing Record 22 of Set 14 | terrace bay
# Processing Record 23 of Set 14 | makat
# Processing Record 24 of Set 14 | sao gabriel da cachoeira
# Processing Record 25 of Set 14 | george
# Processing Record 26 of Set 14 | cilegon
# Processing Record 27 of Set 14 | pinotepa nacional
# Processing Record 28 of Set 14 | brae
# Processing Record 29 of Set 14 | grand-lahou
# Processing Record 30 of Set 14 | homer
# Processing Record 31 of Set 14 | dutse
# Processing Record 32 of Set 14 | caconda
# Processing Record 33 of Set 14 | fairbanks
# Processing Record 34 of Set 14 | dezful
# Processing Record 35 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 36 of Set 14 | thanh hoa
# Processing Record 37 of Set 14 | mehran
# Processing Record 38 of Set 14 | rorvik
# Processing Record 39 of Set 14 | japura
# Processing Record 40 of Set 14 | auki
# Processing Record 41 of Set 14 | kitgum
# Processing Record 42 of Set 14 | selikhino
# Processing Record 43 of Set 14 | casper
# Processing Record 44 of Set 14 | ahipara
# Processing Record 45 of Set 14 | challapata
# Processing Record 46 of Set 14 | tessalit
# Processing Record 47 of Set 14 | cascais
# Processing Record 48 of Set 14 | gimbi
# Processing Record 49 of Set 14 | kheri
# Processing Record 50 of Set 14 | mikuni
# Processing Record 1 of Set 15 | mons
# Processing Record 2 of Set 15 | kemijarvi
# Processing Record 3 of Set 15 | siocon
# Processing Record 4 of Set 15 | grand-bourg
# Processing Record 5 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 15 | wilkie
# Processing Record 7 of Set 15 | ponta delgada
# Processing Record 8 of Set 15 | weyburn
# Processing Record 9 of Set 15 | morwell
# Processing Record 10 of Set 15 | zlatoustovsk
# City not found. Skipping...
# Processing Record 11 of Set 15 | lima
# Processing Record 12 of Set 15 | visnes
# Processing Record 13 of Set 15 | bonfim
# Processing Record 14 of Set 15 | anapskaya
# Processing Record 15 of Set 15 | liuli
# Processing Record 16 of Set 15 | saint-louis
# Processing Record 17 of Set 15 | cap-aux-meules
# Processing Record 18 of Set 15 | magnitka
# Processing Record 19 of Set 15 | springville
# Processing Record 20 of Set 15 | isangel
# Processing Record 21 of Set 15 | sao jose da coroa grande
# Processing Record 22 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 15 | pitimbu
# Processing Record 24 of Set 15 | skjervoy
# Processing Record 25 of Set 15 | de aar
# Processing Record 26 of Set 15 | massakory
# Processing Record 27 of Set 15 | libertador general san martin
# Processing Record 28 of Set 15 | evensk
# Processing Record 29 of Set 15 | sinaloa
# Processing Record 30 of Set 15 | taksimo
# Processing Record 31 of Set 15 | mahuva
# Processing Record 32 of Set 15 | nakamura
# Processing Record 33 of Set 15 | beringovskiy
# Processing Record 34 of Set 15 | comodoro rivadavia
# Processing Record 35 of Set 15 | shubarshi
# Processing Record 36 of Set 15 | nokha
# Processing Record 37 of Set 15 | reefton
# City not found. Skipping...
# Processing Record 38 of Set 15 | mareeba
# Processing Record 39 of Set 15 | tacuarembo
# Processing Record 40 of Set 15 | abilene
# Processing Record 41 of Set 15 | aykhal
# Processing Record 42 of Set 15 | luanda
# Processing Record 43 of Set 15 | skjold
# Processing Record 44 of Set 15 | paracuru
# Processing Record 45 of Set 15 | dargaville
# Processing Record 46 of Set 15 | innisfail
# Processing Record 47 of Set 15 | praia da vitoria
# Processing Record 48 of Set 15 | alice springs
# Processing Record 49 of Set 15 | eugene
# Processing Record 50 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 16 | marienburg
# Processing Record 2 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 16 | phangnga
# Processing Record 4 of Set 16 | batagay-alyta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Asnaes      DK  55.8123   11.5013     34.05        91          99
# 1          Dolores      AR -36.3132  -57.6792     63.19        47          35
# 2     Port Hedland      AU -20.3167  118.5667     82.45        89         100
# 3             Tual      ID  -5.6667  132.7500     83.91        74         100
# 4          Te Anau      NZ -45.4167  167.7167     70.72        48          87
# 5  Bandar-E Lengeh      IR  26.5579   54.8807     69.19        59           0
# 6        Cape Town      ZA -33.9258   18.4232     75.11        81           0
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     76.96        86         100
# 8            Romny      UA  50.7510   33.4747     26.98        96          97
# 9      Yellowknife      CA  62.4560 -114.3525     -7.58        78          20
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1        8.59    scattered clouds
# 2        4.61     overcast clouds
# 3       20.29     overcast clouds
# 4        2.04     overcast clouds
# 5        2.04           clear sky
# 6        1.01           clear sky
# 7        6.22     overcast clouds
# 8       12.93          light snow
# 9        9.22          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Asnaes      DK  55.8123   11.5013     34.05        91          99
# 1          Dolores      AR -36.3132  -57.6792     63.19        47          35
# 2     Port Hedland      AU -20.3167  118.5667     82.45        89         100
# 3             Tual      ID  -5.6667  132.7500     83.91        74         100
# 4          Te Anau      NZ -45.4167  167.7167     70.72        48          87
# 5  Bandar-E Lengeh      IR  26.5579   54.8807     69.19        59           0
# 6        Cape Town      ZA -33.9258   18.4232     75.11        81           0
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     76.96        86         100
# 8            Romny      UA  50.7510   33.4747     26.98        96          97
# 9      Yellowknife      CA  62.4560 -114.3525     -7.58        78          20
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1        8.59    scattered clouds
# 2        4.61     overcast clouds
# 3       20.29     overcast clouds
# 4        2.04     overcast clouds
# 5        2.04           clear sky
# 6        1.01           clear sky
# 7        6.22     overcast clouds
# 8       12.93          light snow
# 9        9.22          few clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv')

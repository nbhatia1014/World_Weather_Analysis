# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8017826767103057fe931e3812d00934

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Cloudiness": city_clouds,
                          "Country": city_country,
                          "Date": city_date,
                          "Humidity": city_humidity,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | channel-port aux basques
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | tessalit
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | nuuk
# Processing Record 6 of Set 1 | port lincoln
# Processing Record 7 of Set 1 | northam
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | dagua
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | bereda
# Processing Record 17 of Set 1 | prince george
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | srednekolymsk
# Processing Record 20 of Set 1 | ler
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | villazon
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | torbay
# Processing Record 25 of Set 1 | ahuimanu
# Processing Record 26 of Set 1 | tefe
# Processing Record 27 of Set 1 | namatanai
# Processing Record 28 of Set 1 | airai
# Processing Record 29 of Set 1 | kinango
# Processing Record 30 of Set 1 | itoman
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | mount isa
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | nyuzen
# Processing Record 39 of Set 1 | cap malheureux
# Processing Record 40 of Set 1 | chickasha
# Processing Record 41 of Set 1 | inhambane
# Processing Record 42 of Set 1 | buala
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | egvekinot
# Processing Record 45 of Set 1 | rudnogorsk
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | emerald
# Processing Record 49 of Set 1 | humberto de campos
# Processing Record 50 of Set 1 | george
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | vila velha
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | bima
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | dingli
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | barguzin
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | nha trang
# Processing Record 11 of Set 2 | vardo
# Processing Record 12 of Set 2 | zomba
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | sao jose da coroa grande
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | gat
# Processing Record 18 of Set 2 | zhigansk
# Processing Record 19 of Set 2 | marawi
# Processing Record 20 of Set 2 | zheleznodorozhnyy
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | darlowo
# Processing Record 23 of Set 2 | latung
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | plettenberg bay
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | abu kamal
# Processing Record 29 of Set 2 | jiangyou
# Processing Record 30 of Set 2 | launceston
# Processing Record 31 of Set 2 | taoudenni
# Processing Record 32 of Set 2 | barra do garcas
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | mataura
# Processing Record 35 of Set 2 | cairns
# Processing Record 36 of Set 2 | pathalgaon
# Processing Record 37 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 2 | chengzihe
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | burns lake
# Processing Record 41 of Set 2 | jieshi
# Processing Record 42 of Set 2 | buyukcavuslu
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 2 | bournemouth
# Processing Record 50 of Set 2 | shamkhal
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | port macquarie
# Processing Record 4 of Set 3 | vizinga
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | burnie
# Processing Record 7 of Set 3 | can tho
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | olinda
# Processing Record 11 of Set 3 | kenai
# Processing Record 12 of Set 3 | catia la mar
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | bjornevatn
# Processing Record 17 of Set 3 | khasan
# Processing Record 18 of Set 3 | takoradi
# Processing Record 19 of Set 3 | bam
# Processing Record 20 of Set 3 | iturama
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | amvrosiyivka
# Processing Record 23 of Set 3 | bonavista
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 27 of Set 3 | kibala
# Processing Record 28 of Set 3 | champoton
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | faya
# Processing Record 35 of Set 3 | fairview
# Processing Record 36 of Set 3 | riyadh
# Processing Record 37 of Set 3 | fortuna
# Processing Record 38 of Set 3 | flinders
# Processing Record 39 of Set 3 | sabang
# Processing Record 40 of Set 3 | rantepao
# Processing Record 41 of Set 3 | havre-saint-pierre
# Processing Record 42 of Set 3 | verkhniye kigi
# Processing Record 43 of Set 3 | itarema
# Processing Record 44 of Set 3 | makushino
# Processing Record 45 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 3 | san jose iturbide
# Processing Record 47 of Set 3 | san cristobal
# Processing Record 48 of Set 3 | half moon bay
# Processing Record 49 of Set 3 | pergamino
# Processing Record 50 of Set 3 | mporokoso
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | belaya gora
# Processing Record 3 of Set 4 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | conakry
# Processing Record 6 of Set 4 | biak
# Processing Record 7 of Set 4 | graaff-reinet
# Processing Record 8 of Set 4 | yumaguzino
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | siaya
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | belyy yar
# Processing Record 13 of Set 4 | fenoarivo atsinanana
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | tromso
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | puerto escondido
# Processing Record 19 of Set 4 | homer
# Processing Record 20 of Set 4 | sarangani
# Processing Record 21 of Set 4 | bandipur
# Processing Record 22 of Set 4 | uruzgan
# Processing Record 23 of Set 4 | uvira
# Processing Record 24 of Set 4 | mecca
# Processing Record 25 of Set 4 | cururupu
# Processing Record 26 of Set 4 | elverum
# Processing Record 27 of Set 4 | bulgan
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | severo-yeniseyskiy
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | oistins
# Processing Record 32 of Set 4 | yatou
# Processing Record 33 of Set 4 | kaitangata
# Processing Record 34 of Set 4 | vao
# Processing Record 35 of Set 4 | khatanga
# Processing Record 36 of Set 4 | ust-kan
# Processing Record 37 of Set 4 | seoul
# Processing Record 38 of Set 4 | azare
# Processing Record 39 of Set 4 | antofagasta
# Processing Record 40 of Set 4 | lorengau
# Processing Record 41 of Set 4 | praia da vitoria
# Processing Record 42 of Set 4 | bathsheba
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 4 | kozan
# Processing Record 46 of Set 4 | dunmore east
# Processing Record 47 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 48 of Set 4 | orativ
# Processing Record 49 of Set 4 | noumea
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | grootfontein
# Processing Record 3 of Set 5 | keita
# Processing Record 4 of Set 5 | hami
# Processing Record 5 of Set 5 | narsaq
# Processing Record 6 of Set 5 | beringovskiy
# Processing Record 7 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 5 | huilong
# Processing Record 9 of Set 5 | dhidhdhoo
# Processing Record 10 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | faranah
# Processing Record 13 of Set 5 | ngunguru
# Processing Record 14 of Set 5 | botwood
# Processing Record 15 of Set 5 | east london
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | sandnessjoen
# Processing Record 21 of Set 5 | shellbrook
# Processing Record 22 of Set 5 | georgetown
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | rio grande
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | cape town
# Processing Record 28 of Set 5 | lasa
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | krasnoarmeyskoye
# Processing Record 31 of Set 5 | pandan
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | changji
# Processing Record 35 of Set 5 | yanam
# Processing Record 36 of Set 5 | marsa matruh
# Processing Record 37 of Set 5 | biala podlaska
# Processing Record 38 of Set 5 | porto novo
# Processing Record 39 of Set 5 | birjand
# Processing Record 40 of Set 5 | kavaratti
# Processing Record 41 of Set 5 | singkang
# Processing Record 42 of Set 5 | benton harbor
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | bambanglipuro
# Processing Record 45 of Set 5 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 46 of Set 5 | kapit
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | tiksi
# Processing Record 49 of Set 5 | kailua
# Processing Record 50 of Set 5 | chuy
# Processing Record 1 of Set 6 | harper
# Processing Record 2 of Set 6 | strezhevoy
# Processing Record 3 of Set 6 | mayo
# Processing Record 4 of Set 6 | hastings
# Processing Record 5 of Set 6 | thompson
# Processing Record 6 of Set 6 | terra nova
# Processing Record 7 of Set 6 | palmer
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | troy
# Processing Record 10 of Set 6 | los llanos de aridane
# Processing Record 11 of Set 6 | pasighat
# Processing Record 12 of Set 6 | solnechnyy
# Processing Record 13 of Set 6 | gravdal
# Processing Record 14 of Set 6 | takaka
# Processing Record 15 of Set 6 | aswan
# Processing Record 16 of Set 6 | bara
# Processing Record 17 of Set 6 | necochea
# Processing Record 18 of Set 6 | teterow
# Processing Record 19 of Set 6 | giaveno
# Processing Record 20 of Set 6 | atar
# Processing Record 21 of Set 6 | catuday
# Processing Record 22 of Set 6 | kiruna
# Processing Record 23 of Set 6 | mantua
# Processing Record 24 of Set 6 | okha
# Processing Record 25 of Set 6 | oranjemund
# Processing Record 26 of Set 6 | port blair
# Processing Record 27 of Set 6 | panipat
# Processing Record 28 of Set 6 | mount darwin
# Processing Record 29 of Set 6 | batagay
# Processing Record 30 of Set 6 | pangkalanbuun
# Processing Record 31 of Set 6 | tual
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | kertosono
# Processing Record 35 of Set 6 | meulaboh
# Processing Record 36 of Set 6 | khovu-aksy
# Processing Record 37 of Set 6 | labuan
# Processing Record 38 of Set 6 | kirensk
# Processing Record 39 of Set 6 | qandala
# Processing Record 40 of Set 6 | kumluca
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | priiskovyy
# Processing Record 43 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | taltal
# Processing Record 46 of Set 6 | yashalta
# Processing Record 47 of Set 6 | ahipara
# Processing Record 48 of Set 6 | alencon
# Processing Record 49 of Set 6 | melipilla
# Processing Record 50 of Set 6 | mehamn
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | sinnamary
# Processing Record 3 of Set 7 | port hardy
# Processing Record 4 of Set 7 | camacha
# Processing Record 5 of Set 7 | a
# City not found. Skipping...
# Processing Record 6 of Set 7 | licheng
# Processing Record 7 of Set 7 | paita
# Processing Record 8 of Set 7 | ust-omchug
# Processing Record 9 of Set 7 | inta
# Processing Record 10 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | dubbo
# Processing Record 13 of Set 7 | mwene-ditu
# Processing Record 14 of Set 7 | sierra vista
# Processing Record 15 of Set 7 | jizan
# Processing Record 16 of Set 7 | harlingen
# Processing Record 17 of Set 7 | itupiranga
# Processing Record 18 of Set 7 | monrovia
# Processing Record 19 of Set 7 | corralillo
# Processing Record 20 of Set 7 | makakilo city
# Processing Record 21 of Set 7 | nicosia
# Processing Record 22 of Set 7 | villa carlos paz
# Processing Record 23 of Set 7 | te anau
# Processing Record 24 of Set 7 | camocim
# Processing Record 25 of Set 7 | sakakah
# Processing Record 26 of Set 7 | tursunzoda
# Processing Record 27 of Set 7 | kastamonu
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | yingshang
# City not found. Skipping...
# Processing Record 30 of Set 7 | mamallapuram
# Processing Record 31 of Set 7 | ocote paulino
# Processing Record 32 of Set 7 | lampa
# Processing Record 33 of Set 7 | hualmay
# Processing Record 34 of Set 7 | nanyang
# Processing Record 35 of Set 7 | andros town
# Processing Record 36 of Set 7 | pelym
# Processing Record 37 of Set 7 | ust-maya
# Processing Record 38 of Set 7 | yerbogachen
# Processing Record 39 of Set 7 | talnakh
# Processing Record 40 of Set 7 | darab
# Processing Record 41 of Set 7 | katangli
# Processing Record 42 of Set 7 | sevierville
# Processing Record 43 of Set 7 | toyooka
# Processing Record 44 of Set 7 | bani walid
# Processing Record 45 of Set 7 | marsh harbour
# Processing Record 46 of Set 7 | milkovo
# Processing Record 47 of Set 7 | oyama
# Processing Record 48 of Set 7 | kargasok
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | surt
# Processing Record 1 of Set 8 | constitucion
# Processing Record 2 of Set 8 | salaga
# Processing Record 3 of Set 8 | hamilton
# Processing Record 4 of Set 8 | vestmanna
# Processing Record 5 of Set 8 | teguldet
# Processing Record 6 of Set 8 | kavieng
# Processing Record 7 of Set 8 | eloy
# Processing Record 8 of Set 8 | novy malin
# Processing Record 9 of Set 8 | dawlatabad
# Processing Record 10 of Set 8 | bardiyah
# Processing Record 11 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 8 | mackay
# Processing Record 13 of Set 8 | nelson bay
# Processing Record 14 of Set 8 | altay
# Processing Record 15 of Set 8 | davila
# Processing Record 16 of Set 8 | yar-sale
# Processing Record 17 of Set 8 | anadyr
# Processing Record 18 of Set 8 | saldanha
# Processing Record 19 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 8 | padang
# Processing Record 21 of Set 8 | qasigiannguit
# Processing Record 22 of Set 8 | emmett
# Processing Record 23 of Set 8 | contai
# Processing Record 24 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 25 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 8 | kupang
# Processing Record 27 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 8 | tahoua
# Processing Record 29 of Set 8 | baykit
# Processing Record 30 of Set 8 | koumac
# Processing Record 31 of Set 8 | kalmunai
# Processing Record 32 of Set 8 | emba
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | edd
# Processing Record 36 of Set 8 | cayenne
# Processing Record 37 of Set 8 | boende
# Processing Record 38 of Set 8 | bambous virieux
# Processing Record 39 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 40 of Set 8 | whitianga
# Processing Record 41 of Set 8 | sterling
# Processing Record 42 of Set 8 | burica
# City not found. Skipping...
# Processing Record 43 of Set 8 | hambantota
# Processing Record 44 of Set 8 | rock sound
# Processing Record 45 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 8 | aktanysh
# Processing Record 47 of Set 8 | glossa
# Processing Record 48 of Set 8 | dudinka
# Processing Record 49 of Set 8 | mwingi
# Processing Record 50 of Set 8 | cherskiy
# Processing Record 1 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 9 | tignere
# Processing Record 3 of Set 9 | ambilobe
# Processing Record 4 of Set 9 | praia
# Processing Record 5 of Set 9 | taurage
# Processing Record 6 of Set 9 | antalaha
# Processing Record 7 of Set 9 | volodarskiy
# Processing Record 8 of Set 9 | hangu
# Processing Record 9 of Set 9 | kyzyl-suu
# Processing Record 10 of Set 9 | pacific grove
# Processing Record 11 of Set 9 | coihaique
# Processing Record 12 of Set 9 | araouane
# Processing Record 13 of Set 9 | luanda
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | brainerd
# Processing Record 16 of Set 9 | port hedland
# Processing Record 17 of Set 9 | puerto narino
# Processing Record 18 of Set 9 | ardakan
# Processing Record 19 of Set 9 | faanui
# Processing Record 20 of Set 9 | uttaradit
# Processing Record 21 of Set 9 | poya
# Processing Record 22 of Set 9 | kloulklubed
# Processing Record 23 of Set 9 | agadez
# Processing Record 24 of Set 9 | ellensburg
# Processing Record 25 of Set 9 | manresa
# Processing Record 26 of Set 9 | laguna
# Processing Record 27 of Set 9 | nalut
# Processing Record 28 of Set 9 | college
# Processing Record 29 of Set 9 | kingman
# Processing Record 30 of Set 9 | mezen
# Processing Record 31 of Set 9 | asau
# Processing Record 32 of Set 9 | comodoro rivadavia
# Processing Record 33 of Set 9 | tautira
# Processing Record 34 of Set 9 | cidreira
# Processing Record 35 of Set 9 | san matias
# Processing Record 36 of Set 9 | alice springs
# Processing Record 37 of Set 9 | rwamagana
# Processing Record 38 of Set 9 | fairbanks
# Processing Record 39 of Set 9 | cockburn town
# Processing Record 40 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 41 of Set 9 | sorong
# Processing Record 42 of Set 9 | betsiamites
# Processing Record 43 of Set 9 | tiarei
# Processing Record 44 of Set 9 | ulladulla
# Processing Record 45 of Set 9 | ancud
# Processing Record 46 of Set 9 | ouesso
# Processing Record 47 of Set 9 | borovichi
# Processing Record 48 of Set 9 | nakatsu
# Processing Record 49 of Set 9 | bardstown
# Processing Record 50 of Set 9 | sorland
# Processing Record 1 of Set 10 | ballyshannon
# Processing Record 2 of Set 10 | ystad
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | karoi
# Processing Record 5 of Set 10 | iwanai
# Processing Record 6 of Set 10 | slave lake
# Processing Record 7 of Set 10 | chara
# Processing Record 8 of Set 10 | west wendover
# Processing Record 9 of Set 10 | nuevitas
# Processing Record 10 of Set 10 | cervo
# Processing Record 11 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 10 | port augusta
# Processing Record 13 of Set 10 | lynchburg
# Processing Record 14 of Set 10 | storsteinnes
# Processing Record 15 of Set 10 | putnok
# Processing Record 16 of Set 10 | manadhoo
# Processing Record 17 of Set 10 | bikaner
# Processing Record 18 of Set 10 | mareeba
# Processing Record 19 of Set 10 | mangit
# Processing Record 20 of Set 10 | lerwick
# Processing Record 21 of Set 10 | zhangye
# Processing Record 22 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 10 | ugoofaaru
# Processing Record 24 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 10 | panama city
# Processing Record 26 of Set 10 | dawei
# Processing Record 27 of Set 10 | salina cruz
# Processing Record 28 of Set 10 | moron
# Processing Record 29 of Set 10 | alyangula
# Processing Record 30 of Set 10 | san policarpo
# Processing Record 31 of Set 10 | santa isabel
# Processing Record 32 of Set 10 | richards bay
# Processing Record 33 of Set 10 | colombo
# Processing Record 34 of Set 10 | republic
# Processing Record 35 of Set 10 | goderich
# Processing Record 36 of Set 10 | brazzaville
# Processing Record 37 of Set 10 | carmelo
# Processing Record 38 of Set 10 | shubarshi
# Processing Record 39 of Set 10 | gouyave
# Processing Record 40 of Set 10 | suez
# Processing Record 41 of Set 10 | husavik
# Processing Record 42 of Set 10 | nantucket
# Processing Record 43 of Set 10 | varangaon
# Processing Record 44 of Set 10 | marienburg
# Processing Record 45 of Set 10 | yabrud
# Processing Record 46 of Set 10 | saint-pierre
# Processing Record 47 of Set 10 | acajutla
# Processing Record 48 of Set 10 | alta gracia
# Processing Record 49 of Set 10 | ailigandi
# Processing Record 50 of Set 10 | teguise
# Processing Record 1 of Set 11 | dunedin
# Processing Record 2 of Set 11 | colares
# Processing Record 3 of Set 11 | calatrava
# Processing Record 4 of Set 11 | mumford
# Processing Record 5 of Set 11 | eyl
# Processing Record 6 of Set 11 | clearwater
# Processing Record 7 of Set 11 | tunceli
# Processing Record 8 of Set 11 | fare
# Processing Record 9 of Set 11 | luderitz
# Processing Record 10 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 11 | baruun-urt
# Processing Record 12 of Set 11 | mogadishu
# Processing Record 13 of Set 11 | henties bay
# Processing Record 14 of Set 11 | san angelo
# Processing Record 15 of Set 11 | ola
# Processing Record 16 of Set 11 | lakes entrance
# Processing Record 17 of Set 11 | lubango
# Processing Record 18 of Set 11 | loralai
# Processing Record 19 of Set 11 | taitung
# Processing Record 20 of Set 11 | lavrentiya
# Processing Record 21 of Set 11 | bodden town
# Processing Record 22 of Set 11 | hirara
# Processing Record 23 of Set 11 | calinesti
# Processing Record 24 of Set 11 | polewali
# Processing Record 25 of Set 11 | port moresby
# Processing Record 26 of Set 11 | ridgecrest
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | avera
# Processing Record 29 of Set 11 | pitimbu
# Processing Record 30 of Set 11 | hadsten
# Processing Record 31 of Set 11 | dzaoudzi
# Processing Record 32 of Set 11 | balaipungut
# Processing Record 33 of Set 11 | bubaque
# Processing Record 34 of Set 11 | ust-nera
# Processing Record 35 of Set 11 | kuandian
# Processing Record 36 of Set 11 | jiexiu
# Processing Record 37 of Set 11 | kirkland lake
# Processing Record 38 of Set 11 | hobyo
# Processing Record 39 of Set 11 | fagernes
# Processing Record 40 of Set 11 | ostrovnoy
# Processing Record 41 of Set 11 | san luis
# Processing Record 42 of Set 11 | bajah
# Processing Record 43 of Set 11 | ventersburg
# Processing Record 44 of Set 11 | troitsko-pechorsk
# Processing Record 45 of Set 11 | tazovskiy
# Processing Record 46 of Set 11 | honiara
# Processing Record 47 of Set 11 | san jeronimito
# Processing Record 48 of Set 11 | ferrol
# Processing Record 49 of Set 11 | talaya
# Processing Record 50 of Set 11 | astoria
# Processing Record 1 of Set 12 | taksimo
# Processing Record 2 of Set 12 | clearlake
# Processing Record 3 of Set 12 | puri
# Processing Record 4 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 12 | salalah
# Processing Record 6 of Set 12 | carauari
# Processing Record 7 of Set 12 | pisco
# Processing Record 8 of Set 12 | hofn
# Processing Record 9 of Set 12 | ascension
# Processing Record 10 of Set 12 | lata
# Processing Record 11 of Set 12 | abashiri
# Processing Record 12 of Set 12 | mazatlan
# Processing Record 13 of Set 12 | ferme-neuve
# Processing Record 14 of Set 12 | kaeo
# Processing Record 15 of Set 12 | alugan
# Processing Record 16 of Set 12 | rocha
# Processing Record 17 of Set 12 | acapulco
# Processing Record 18 of Set 12 | tikrit
# Processing Record 19 of Set 12 | eregli
# Processing Record 20 of Set 12 | genhe
# Processing Record 21 of Set 12 | arman
# Processing Record 22 of Set 12 | aquiraz
# Processing Record 23 of Set 12 | yeniseysk
# Processing Record 24 of Set 12 | ishigaki
# Processing Record 25 of Set 12 | peniche
# Processing Record 26 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 12 | houma
# Processing Record 28 of Set 12 | chernyshevskiy
# Processing Record 29 of Set 12 | guilin
# Processing Record 30 of Set 12 | puyang
# Processing Record 31 of Set 12 | donegal
# Processing Record 32 of Set 12 | tahta
# Processing Record 33 of Set 12 | jaque
# Processing Record 34 of Set 12 | odienne
# Processing Record 35 of Set 12 | mongoumba
# Processing Record 36 of Set 12 | qarqin
# Processing Record 37 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 12 | pangnirtung
# Processing Record 39 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 12 | billings
# Processing Record 41 of Set 12 | eucaliptus
# Processing Record 42 of Set 12 | morondava
# Processing Record 43 of Set 12 | primero de enero
# Processing Record 44 of Set 12 | taos
# Processing Record 45 of Set 12 | tshela
# Processing Record 46 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 47 of Set 12 | baijiantan
# Processing Record 48 of Set 12 | okhotsk
# Processing Record 49 of Set 12 | freeport
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | kimbe
# Processing Record 2 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 3 of Set 13 | quthing
# Processing Record 4 of Set 13 | virginia beach
# Processing Record 5 of Set 13 | roma
# Processing Record 6 of Set 13 | maribo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City  Cloudiness Country                 Date  \
# 0  Channel-Port Aux Basques         100      CA  2022-01-31 21:45:05
# 1                  Hermanus          14      ZA  2022-01-31 21:47:04
# 2                  Tessalit          49      ML  2022-01-31 21:48:08
# 3                     Lagoa          26      PT  2022-01-31 21:48:08
# 4                      Nuuk         100      GL  2022-01-31 21:48:09
# 5              Port Lincoln          57      AU  2022-01-31 21:48:10
# 6                   Northam          81      GB  2022-01-31 21:48:10
# 7                    Hobart          20      AU  2022-01-31 21:44:27
# 8                   Isangel         100      VU  2022-01-31 21:47:12
# 9               Yellowknife          20      CA  2022-01-31 21:46:17
#
#    Humidity      Lat       Lng  Max Temp  Wind Speed
# 0        67  47.5702  -59.1367     22.78       22.37
# 1        83 -34.4187   19.2345     74.89        9.35
# 2        12  20.1986    1.0114     67.14       10.49
# 3        79  39.0500  -27.9833     58.69       24.38
# 4        63  64.1835  -51.7216     20.01        4.61
# 5        76 -34.7333  135.8667     64.08       18.88
# 6        87  51.0333   -4.2167     48.61       16.84
# 7        76 -42.8794  147.3294     75.06        1.01
# 8        94 -19.5500  169.2667     80.71        5.75
# 9        78  62.4560 -114.3525     -7.58       11.50

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Busselton
# Cloudiness                     24
# Country                        AU
# Date          2022-01-31 21:45:27
# Humidity                       64
# Lat                        -33.65
# Lng                      115.3333
# Max Temp                    57.09
# Wind Speed                  15.23
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 555    False
# 556    False
# 557     True
# 558     True
# 559     True
# Name: Lat, Length: 560, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#                        City  Cloudiness Country                 Date  \
# 0  Channel-Port Aux Basques         100      CA  2022-01-31 21:45:05
# 2                  Tessalit          49      ML  2022-01-31 21:48:08
# 3                     Lagoa          26      PT  2022-01-31 21:48:08
# 4                      Nuuk         100      GL  2022-01-31 21:48:09
# 6                   Northam          81      GB  2022-01-31 21:48:10
#
#    Humidity      Lat      Lng  Max Temp  Wind Speed
# 0        67  47.5702 -59.1367     22.78       22.37
# 2        12  20.1986   1.0114     67.14       10.49
# 3        79  39.0500 -27.9833     58.69       24.38
# 4        63  64.1835 -51.7216     20.01        4.61
# 6        87  51.0333  -4.2167     48.61       16.84

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
